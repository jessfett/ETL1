# %% [markdown]
# # Scrape Payroll

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas import DataFrame

# %%
 # URL of page to be scraped
url = 'https://www.cbssports.com/mlb/news/2019-mlb-opening-day-payrolls-red-sox-cubs-yankees-open-season-above-competitive-balance-tax-threshold/'

# %%
tables = pd.read_html(url)
tables
# Out:
# [    Rank                   Team Opening Day payroll Estimated CBT payroll
#  0      1         Boston Red Sox        $213,188,334          $248,633,334
#  1      2           Chicago Cubs        $208,199,143          $225,199,143
#  2      3       New York Yankees        $206,407,750          $223,407,750
#  3      4   Washington Nationals        $181,400,409          $198,542,076
#  4      5         Houston Astros        $177,443,329          $194,443,329
#  5      6  Philadelphia Phillies        $172,374,782          $189,374,782
#  6      7     Los Angeles Angels        $167,456,465          $184,456,465
#  7      8          New York Mets        $161,865,003          $196,115,003
#  8      9    Los Angeles Dodgers        $152,863,333          $198,338,333
#  9     10    St. Louis Cardinals        $150,367,083          $174,190,855
#  10    11       Colorado Rockies        $149,335,166          $166,335,166
# ...

# %%
type(tables)
# Out:
# list

# %%
salary_df = tables[0]
salary_df.head()
# Out:
#    Rank                  Team Opening Day payroll Estimated CBT payroll
# 0     1        Boston Red Sox        $213,188,334          $248,633,334
# 1     2          Chicago Cubs        $208,199,143          $225,199,143
# 2     3      New York Yankees        $206,407,750          $223,407,750
# 3     4  Washington Nationals        $181,400,409          $198,542,076
# 4     5        Houston Astros        $177,443,329          $194,443,329

# %%
salary=salary_df.rename(columns={'Rank':"SALARYRANK", 'Team': "TEAMNAME", "Opening Day payroll": "OPENINGDAYPAYROLL", 'Estimated CBT payroll': 'CBTPAYROLL'})

salary
# Out:
#     SALARYRANK               TEAMNAME OPENINGDAYPAYROLL    CBTPAYROLL
# 0            1         Boston Red Sox      $213,188,334  $248,633,334
# 1            2           Chicago Cubs      $208,199,143  $225,199,143
# 2            3       New York Yankees      $206,407,750  $223,407,750
# 3            4   Washington Nationals      $181,400,409  $198,542,076
# 4            5         Houston Astros      $177,443,329  $194,443,329
# 5            6  Philadelphia Phillies      $172,374,782  $189,374,782
# 6            7     Los Angeles Angels      $167,456,465  $184,456,465
# 7            8          New York Mets      $161,865,003  $196,115,003
# 8            9    Los Angeles Dodgers      $152,863,333  $198,338,333
# 9           10    St. Louis Cardinals      $150,367,083  $174,190,855
# 10          11       Colorado Rockies      $149,335,166  $166,335,166
# 11          12   San Francisco Giants      $138,030,231  $155,030,231
# ...

# %% [markdown]
# # TEAM STATS

# %%
 # Store filepath in a variable
file_one = "Resources/Teams.csv"

# %%
# Read our Data file with the pandas library
stats_df = pd.read_csv(file_one)

# %%
stats_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
stats2019 = stats_df[stats_df["yearID"] == 2019]

# %%
display(list(stats2019.columns.values))
# Out:
# ['yearID',
#  'lgID',
#  'teamID',
#  'franchID',
#  'divID',
#  'Rank',
#  'G',
#  'Ghome',
#  'W',
#  'L',
#  'DivWin',
#  'WCWin',
#  'LgWin',
#  'WSWin',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'CS',
#  'HBP',
#  'SF',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SV',
#  'IPouts',
#  'HA',
#  'HRA',
#  'BBA',
#  'SOA',
#  'E',
#  'DP',
#  'FP',
#  'name',
#  'park',
#  'attendance',
#  'BPF',
#  'PPF',
#  'teamIDBR',
#  'teamIDlahman45',
#  'teamIDretro']

# %% [markdown]
# # Clean Data

# %%
stats2019.reset_index()
# Out:
#     index  yearID lgID teamID franchID divID  Rank    G  Ghome    W  ...   DP  \
# 0    2895    2019   NL    ARI      ARI     W     2  162   81.0   85  ...  136
# 1    2896    2019   NL    ATL      ATL     E     1  162   81.0   97  ...  154
# 2    2897    2019   AL    BAL      BAL     E     5  162   81.0   54  ...  155
# 3    2898    2019   AL    BOS      BOS     E     3  162   81.0   84  ...  115
# 4    2899    2019   AL    CHA      CHW     C     3  161   80.0   72  ...  171
# 5    2900    2019   NL    CHN      CHC     C     3  162   81.0   84  ...  141
# 6    2901    2019   NL    CIN      CIN     C     4  162   81.0   75  ...  124
# 7    2902    2019   AL    CLE      CLE     C     2  162   81.0   93  ...  110
# 8    2903    2019   NL    COL      COL     W     4  162   81.0   71  ...  165
# 9    2904    2019   AL    DET      DET     C     5  161   81.0   47  ...  127
# 10   2905    2019   AL    HOU      HOU     W     1  162   81.0  107  ...   96
# ...

# %%
#Rename Headers to all CAPS for easy use in SQL
stats2019.rename(columns={"yearID": "YEAR","lgID": "LEAGUE","teamID": "TEAM","divID": "DIVISION",
                          "Rank": "RANK","G": "GAMES","W": "WINS","L": "LOSSES","name": "TEAMNAME",
                           "park": "PARK","attendance": "ATTENDANCE","DivWin": "DIVSIONWIN",
                          "WCWin": "WILDCARDWIN","LgWIN": "LEAGUEWIN","R": "RUNS","AB": "A",
                          "H": "HITS","HR": "HOMERUNS","SO": "STRIKEOUTS","SHO": "DIVISIONWIN", "RA": "OPPONENTRUNS", "ER": "EARNEDRUNS", "LgWin": "DIVISIONCHAMP", "WSWin":"WORLDSERIESCHAMP"}, inplace=True)

stats2019.rename(columns={"DIVSIONWIN": "DIVISIONCHAMP"})

stats2019.head()
# Out:
#       YEAR LEAGUE TEAM franchID DIVISION  RANK  GAMES  Ghome  WINS  LOSSES  \
# 2895  2019     NL  ARI      ARI        W     2    162   81.0    85      77
# 2896  2019     NL  ATL      ATL        E     1    162   81.0    97      65
# 2897  2019     AL  BAL      BAL        E     5    162   81.0    54     108
# 2898  2019     AL  BOS      BOS        E     3    162   81.0    84      78
# 2899  2019     AL  CHA      CHW        C     3    161   80.0    72      89
#
#       ...   DP     FP              TEAMNAME                         PARK  \
# 2895  ...  136  0.986  Arizona Diamondbacks                  Chase Field
# 2896  ...  154  0.987        Atlanta Braves                SunTrust Park
# 2897  ...  155  0.982     Baltimore Orioles  Oriole Park at Camden Yards
# 2898  ...  115  0.985        Boston Red Sox               Fenway Park II
# 2899  ...  171  0.980     Chicago White Sox        Guaranteed Rate Field
#
#       ATTENDANCE  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
stats_df=stats2019.drop(columns=['Ghome', 'DP', 'FP', 'BPF', 'PPF', 'teamIDBR', 'teamIDlahman45', "teamIDretro"])
stats_df=stats_df.drop(columns=['franchID'])
stats_df=stats_df.drop(columns=['SV', 'IPouts', 'HA', 'HRA', 'BBA', 'SOA', 'E'])
stats_df=stats_df.drop(columns=['HBP','CS', 'SF'])
stats_df=stats_df.drop(columns=['2B', '3B', 'A'])
stats_df=stats_df.drop(columns=['BB','SB','CG'])
stats_df=stats_df.drop(columns=['YEAR'])

# %%
stats_df.head()
# Out:
#      LEAGUE TEAM DIVISION  RANK  GAMES  WINS  LOSSES DIVSIONWIN WILDCARDWIN  \
# 2895     NL  ARI        W     2    162    85      77          N           N
# 2896     NL  ATL        E     1    162    97      65          Y           N
# 2897     AL  BAL        E     5    162    54     108          N           N
# 2898     AL  BOS        E     3    162    84      78          N           N
# 2899     AL  CHA        C     3    161    72      89          N           N
#
#      DIVISIONCHAMP  ... RUNS  HITS  HOMERUNS  STRIKEOUTS  OPPONENTRUNS  \
# 2895             N  ...  813  1419       220      1360.0           743
# 2896             N  ...  855  1432       249      1467.0           743
# 2897             N  ...  729  1379       213      1435.0           981
# 2898             N  ...  901  1554       245      1382.0           828
# 2899             N  ...  708  1443       182      1549.0           832
#
#       EARNEDRUNS   ERA              TEAMNAME                         PARK  \
# ...

# %%
display(list(stats_df.columns.values))
# Out:
# ['LEAGUE',
#  'TEAM',
#  'DIVISION',
#  'RANK',
#  'GAMES',
#  'WINS',
#  'LOSSES',
#  'DIVSIONWIN',
#  'WILDCARDWIN',
#  'DIVISIONCHAMP',
#  'WORLDSERIESCHAMP',
#  'RUNS',
#  'HITS',
#  'HOMERUNS',
#  'STRIKEOUTS',
#  'OPPONENTRUNS',
#  'EARNEDRUNS',
#  'ERA',
#  'TEAMNAME',
#  'PARK',
#  'ATTENDANCE']

# %%
stats2019_df=stats_df.rename(columns={"WORLDSERIES": "WILDCARDWIN"})

# %%
display(list(stats2019_df.columns.values))
# Out:
# ['LEAGUE',
#  'TEAM',
#  'DIVISION',
#  'RANK',
#  'GAMES',
#  'WINS',
#  'LOSSES',
#  'DIVSIONWIN',
#  'WILDCARDWIN',
#  'DIVISIONCHAMP',
#  'WORLDSERIESCHAMP',
#  'RUNS',
#  'HITS',
#  'HOMERUNS',
#  'STRIKEOUTS',
#  'OPPONENTRUNS',
#  'EARNEDRUNS',
#  'ERA',
#  'TEAMNAME',
#  'PARK',
#  'ATTENDANCE']

# %%
teamstats=stats2019_df.reset_index()

# %%
teamstats
# Out:
#     index LEAGUE TEAM DIVISION  RANK  GAMES  WINS  LOSSES DIVSIONWIN  \
# 0    2895     NL  ARI        W     2    162    85      77          N
# 1    2896     NL  ATL        E     1    162    97      65          Y
# 2    2897     AL  BAL        E     5    162    54     108          N
# 3    2898     AL  BOS        E     3    162    84      78          N
# 4    2899     AL  CHA        C     3    161    72      89          N
# 5    2900     NL  CHN        C     3    162    84      78          N
# 6    2901     NL  CIN        C     4    162    75      87          N
# 7    2902     AL  CLE        C     2    162    93      69          N
# 8    2903     NL  COL        W     4    162    71      91          N
# 9    2904     AL  DET        C     5    161    47     114          N
# 10   2905     AL  HOU        W     1    162   107      55          Y
# 11   2906     AL  KCA        C     4    162    59     103          N
# 12   2907     AL  LAA        W     4    162    72      90          N
# ...

# %%
teamstats_df=teamstats

# %%
teamstat_df=teamstats_df.drop(columns=['TEAMID'])

# %%
teamstat_df
# Out:
#     index LEAGUE TEAM DIVISION  RANK  GAMES  WINS  LOSSES DIVSIONWIN  \
# 0    2895     NL  ARI        W     2    162    85      77          N
# 1    2896     NL  ATL        E     1    162    97      65          Y
# 2    2897     AL  BAL        E     5    162    54     108          N
# 3    2898     AL  BOS        E     3    162    84      78          N
# 4    2899     AL  CHA        C     3    161    72      89          N
# 5    2900     NL  CHN        C     3    162    84      78          N
# 6    2901     NL  CIN        C     4    162    75      87          N
# 7    2902     AL  CLE        C     2    162    93      69          N
# 8    2903     NL  COL        W     4    162    71      91          N
# 9    2904     AL  DET        C     5    161    47     114          N
# 10   2905     AL  HOU        W     1    162   107      55          Y
# 11   2906     AL  KCA        C     4    162    59     103          N
# 12   2907     AL  LAA        W     4    162    72      90          N
# ...

# %% [markdown]
# # MERGE

# %%
combined_df = pd.merge(salary, teamstat,
                                 how='outer', on='TEAMNAME')

# %%
combined_df=combined_df.sort_values(by=['TEAMNAME'])

# %%
combined_df
# Out:
#     TEAMID  SALARYRANK               TEAMNAME OPENINGDAYPAYROLL    CBTPAYROLL
# 17      18          18   Arizona Diamondbacks      $107,584,167  $124,584,167
# 16      17          17         Atlanta Braves      $110,530,000  $127,911,060
# 26      27          27      Baltimore Orioles       $67,371,100   $84,371,100
# 0        1           1         Boston Red Sox      $213,188,334  $248,633,334
# 1        2           2           Chicago Cubs      $208,199,143  $225,199,143
# 21      22          22      Chicago White Sox       $96,697,001  $113,697,001
# 14      15          15        Cincinnati Reds      $128,815,238  $145,815,238
# 18      19          19      Cleveland Indians      $107,345,783  $124,345,783
# 10      11          11       Colorado Rockies      $149,335,166  $166,335,166
# 22      23          23         Detroit Tigers       $96,243,400  $113,243,400
# 4        5           5         Houston Astros      $177,443,329  $194,443,329
# ...

# %% [markdown]
# # Subset Dataframes

# %%
#LookUp Table
csv2 = csv1[['Acceleration', 'Pressure']].copy()

csv2 = csv1[['Acceleration', 'Pressure']].copy()

csv2 = csv1[['Acceleration', 'Pressure']].copy()

csv2 = csv1[['Acceleration', 'Pressure']].copy()

csv2 = csv1[['Acceleration', 'Pressure']].copy()

# %% [markdown]
# # IMPORT TO SQL

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///save_pandas.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2020-11-07 09:01:32,753 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-11-07 09:01:32,760 INFO sqlalchemy.engine.base.Engine ()
# 2020-11-07 09:01:32,779 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-11-07 09:01:32,780 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "Payroll"
save_df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')

# %%
#from sqlalchemy import create_engine
#engine = create_engine('postgresql://scott:tiger@localhost:5434/mydatabase')
#df.to_sql('table_name', engine)

# %%
onetable_df = pd.merge(teamstat_df, combined_df,
                                 how='outer', on='TEAMNAME')

# %%
onetable_df
# Out:
#     index LEAGUE TEAM DIVISION  RANK  GAMES  WINS  LOSSES DIVSIONWIN  \
# 0    2895     NL  ARI        W     2    162    85      77          N
# 1    2896     NL  ATL        E     1    162    97      65          Y
# 2    2897     AL  BAL        E     5    162    54     108          N
# 3    2898     AL  BOS        E     3    162    84      78          N
# 4    2899     AL  CHA        C     3    161    72      89          N
# 5    2900     NL  CHN        C     3    162    84      78          N
# 6    2901     NL  CIN        C     4    162    75      87          N
# 7    2902     AL  CLE        C     2    162    93      69          N
# 8    2903     NL  COL        W     4    162    71      91          N
# 9    2904     AL  DET        C     5    161    47     114          N
# 10   2905     AL  HOU        W     1    162   107      55          Y
# 11   2906     AL  KCA        C     4    162    59     103          N
# 12   2907     AL  LAA        W     4    162    72      90          N
# ...
